# %%
# at the top of the file, before other imports
import warnings

warnings.filterwarnings('ignore')

# no warnings will be printed from now on

# Cahn-Hilliard equation
# ======================
# 
# This demo is implemented in a single Python file,
# :download:`demo_cahn-hilliard.py`, which contains both the variational
# forms and the solver.
# 
# This example demonstrates the solution of a particular nonlinear
# time-dependent fourth-order equation, known as the Cahn-Hilliard
# equation. In particular it demonstrates the use of
# 
# * The built-in Newton solver
# * Advanced use of the base class ``NonlinearProblem``
# * Automatic linearisation
# * A mixed finite element method
# * The :math:`\theta`-method for time-dependent equations
# * User-defined Expressions as Python classes
# * Form compiler options
# * Interpolation of functions
# 
# 
# Equation and problem definition
# -------------------------------
# 
# The Cahn-Hilliard equation is a parabolic equation and is typically
# used to model phase separation in binary mixtures.  It involves
# first-order time derivatives, and second- and fourth-order spatial
# derivatives.  The equation reads:
# 
# .. math::
#    \frac{\partial c}{\partial t} - \nabla \cdot M \left(\nabla\left(\frac{d f}{d c}
#              - \lambda \nabla^{2}c\right)\right) &= 0 \quad {\rm in} \ \Omega, \\
#    M\left(\nabla\left(\frac{d f}{d c} - \lambda \nabla^{2}c\right)\right) \cdot n &= 0 \quad {\rm on} \ \partial\Omega, \\
#    M \lambda \nabla c \cdot n &= 0 \quad {\rm on} \ \partial\Omega.
# 
# where :math:`c` is the unknown field, the function :math:`f` is
# usually non-convex in :math:`c` (a fourth-order polynomial is commonly
# used), :math:`n` is the outward directed boundary normal, and
# :math:`M` is a scalar parameter.
# 
# 
# Mixed form
# ^^^^^^^^^^
# 
# The Cahn-Hilliard equation is a fourth-order equation, so casting it
# in a weak form would result in the presence of second-order spatial
# derivatives, and the problem could not be solved using a standard
# Lagrange finite element basis.  A solution is to rephrase the problem
# as two coupled second-order equations:
# 
# .. math::
#    \frac{\partial c}{\partial t} - \nabla \cdot M \nabla\mu  &= 0 \quad {\rm in} \ \Omega, \\
#    \mu -  \frac{d f}{d c} + \lambda \nabla^{2}c &= 0 \quad {\rm in} \ \Omega.
# 
# The unknown fields are now :math:`c` and :math:`\mu`. The weak
# (variational) form of the problem reads: find :math:`(c, \mu) \in V
# \times V` such that
# 
# .. math::
#    \int_{\Omega} \frac{\partial c}{\partial t} q \, {\rm d} x + \int_{\Omega} M \nabla\mu \cdot \nabla q \, {\rm d} x
#           &= 0 \quad \forall \ q \in V,  \\
#    \int_{\Omega} \mu v \, {\rm d} x - \int_{\Omega} \frac{d f}{d c} v \, {\rm d} x - \int_{\Omega} \lambda \nabla c \cdot \nabla v \, {\rm d} x
#           &= 0 \quad \forall \ v \in V.
# 
# 
# Time discretisation
# ^^^^^^^^^^^^^^^^^^^
# 
# Before being able to solve this problem, the time derivative must be
# dealt with. Apply the :math:`\theta`-method to the mixed weak form of
# the equation:
# 
# .. math::
# 
#    \int_{\Omega} \frac{c_{n+1} - c_{n}}{dt} q \, {\rm d} x + \int_{\Omega} M \nabla \mu_{n+\theta} \cdot \nabla q \, {\rm d} x
#           &= 0 \quad \forall \ q \in V  \\
#    \int_{\Omega} \mu_{n+1} v  \, {\rm d} x - \int_{\Omega} \frac{d f_{n+1}}{d c} v  \, {\rm d} x - \int_{\Omega} \lambda \nabla c_{n+1} \cdot \nabla v \, {\rm d} x
#           &= 0 \quad \forall \ v \in V
# 
# where :math:`dt = t_{n+1} - t_{n}` and :math:`\mu_{n+\theta} =
# (1-\theta) \mu_{n} + \theta \mu_{n+1}`.  The task is: given
# :math:`c_{n}` and :math:`\mu_{n}`, solve the above equation to find
# :math:`c_{n+1}` and :math:`\mu_{n+1}`.
# 
# 
# Demo parameters
# ^^^^^^^^^^^^^^^
# 
# The following domains, functions and time stepping parameters are used
# in this demo:
# 
# * :math:`\Omega = (0, 1) \times (0, 1)` (unit square)
# * :math:`f = 100 c^{2} (1-c)^{2}`
# * :math:`\lambda = 1 \times 10^{-2}`
# * :math:`M = 1`
# * :math:`dt = 5 \times 10^{-6}`
# * :math:`\theta = 0.5`
# 
# 
# Implementation
# --------------
# 
# This demo is implemented in the :download:`demo_cahn-hilliard.py`
# file.
# 
# First, the modules :py:mod:`random` :py:mod:`matplotlib`
# :py:mod:`dolfin` module are imported::

import random
from dolfin import *

# .. index:: Expression
# 
# A class which will be used to represent the initial conditions is then
# created::

# Class representing the intial conditions
class InitialConditions(UserExpression):
    def __init__(self, **kwargs):
        random.seed(2 + MPI.rank(MPI.comm_world))
        super().__init__(**kwargs)
    def eval(self, values, x):
        values[0] = 0.63 + 0.02*(0.5 - random.random())
        values[1] = 0.0
    def value_shape(self):
        return (2,)

# It is a subclass of :py:class:`Expression
# <dolfin.functions.expression.Expression>`. In the constructor
# (``__init__``), the random number generator is seeded. If the program
# is run in parallel, the random number generator is seeded using the
# rank (process number) to ensure a different sequence of numbers on
# each process.  The function ``eval`` returns values for a function of
# dimension two.  For the first component of the function, a randomized
# value is returned.  The method ``value_shape`` declares that the
# :py:class:`Expression <dolfin.functions.expression.Expression>` is
# vector valued with dimension two.
# 
# .. index::
#    single: NonlinearProblem; (in Cahn-Hilliard demo)
# 
# A class which will represent the Cahn-Hilliard in an abstract from for
# use in the Newton solver is now defined. It is a subclass of
# :py:class:`NonlinearProblem <dolfin.cpp.NonlinearProblem>`. ::

# Class for interfacing with the Newton solver
class CahnHilliardEquation(NonlinearProblem):
    def __init__(self, a, L):
        NonlinearProblem.__init__(self)
        self.L = L
        self.a = a
    def F(self, b, x):
        assemble(self.L, tensor=b)
    def J(self, A, x):
        assemble(self.a, tensor=A)

# The constructor (``__init__``) stores references to the bilinear
# (``a``) and linear (``L``) forms. These will used to compute the
# Jacobian matrix and the residual vector, respectively, for use in a
# Newton solver.  The function ``F`` and ``J`` are virtual member
# functions of :py:class:`NonlinearProblem
# <dolfin.cpp.NonlinearProblem>`. The function ``F`` computes the
# residual vector ``b``, and the function ``J`` computes the Jacobian
# matrix ``A``.
# 
# Next, various model parameters are defined::

# Model parameters
lmbda  = 1.0e-02  # surface parameter
dt     = 5.0e-06  # time step
theta  = 0.5      # time stepping family, e.g. theta=1 -> backward Euler, theta=0.5 -> Crank-Nicolson

# .. index::
#    singe: form compiler options; (in Cahn-Hilliard demo)
# 
# It is possible to pass arguments that control aspects of the generated
# code to the form compiler. The lines ::

# Form compiler options
parameters["form_compiler"]["optimize"]     = True
parameters["form_compiler"]["cpp_optimize"] = True

# tell the form to apply optimization strategies in the code generation
# phase and the use compiler optimization flags when compiling the
# generated C++ code. Using the option ``["optimize"] = True`` will
# generally result in faster code (sometimes orders of magnitude faster
# for certain operations, depending on the equation), but it may take
# considerably longer to generate the code and the generation phase may
# use considerably more memory).
# 
# A unit square mesh with 97 (= 96 + 1) vertices in each direction is
# created, and on this mesh a :py:class:`FunctionSpace
# <dolfin.functions.functionspace.FunctionSpace>` ``ME`` is built using
# a pair of linear Lagrangian elements. ::

# Create mesh and build function space
mesh = UnitSquareMesh.create(96, 96, CellType.Type.quadrilateral)
P1 = FiniteElement("Lagrange", mesh.ufl_cell(), 1)
ME = FunctionSpace(mesh, P1*P1)

# Trial and test functions of the space ``ME`` are now defined::

# Define trial and test functions
du    = TrialFunction(ME)
q, v  = TestFunctions(ME)

# .. index:: split functions
# 
# For the test functions, :py:func:`TestFunctions
# <dolfin.functions.function.TestFunctions>` (note the 's' at the end)
# is used to define the scalar test functions ``q`` and ``v``. The
# :py:class:`TrialFunction <dolfin.functions.function.TrialFunction>`
# ``du`` has dimension two. Some mixed objects of the
# :py:class:`Function <dolfin.functions.function.Function>` class on
# ``ME`` are defined to represent :math:`u = (c_{n+1}, \mu_{n+1})` and
# :math:`u0 = (c_{n}, \mu_{n})`, and these are then split into
# sub-functions::

# Define functions
u   = Function(ME)  # current solution
u0  = Function(ME)  # solution from previous converged step

# Split mixed functions
dc, dmu = split(du)
c,  mu  = split(u)
c0, mu0 = split(u0)

# The line ``c, mu = split(u)`` permits direct access to the components
# of a mixed function. Note that ``c`` and ``mu`` are references for
# components of ``u``, and not copies.
# 
# .. index::
#    single: interpolating functions; (in Cahn-Hilliard demo)
# 
# Initial conditions are created by using the class defined at the
# beginning of the demo and then interpolating the initial conditions
# into a finite element space::

# Create intial conditions and interpolate
u_init = InitialConditions(degree=1)
u.interpolate(u_init)
u0.interpolate(u_init)

# The first line creates an object of type ``InitialConditions``.  The
# following two lines make ``u`` and ``u0`` interpolants of ``u_init``
# (since ``u`` and ``u0`` are finite element functions, they may not be
# able to represent a given function exactly, but the function can be
# approximated by interpolating it in a finite element space).
# 
# .. index:: automatic differentiation
# 
# The chemical potential :math:`df/dc` is computed using automated
# differentiation::

# Compute the chemical potential df/dc
c = variable(c)
f    = 100*c**2*(1-c)**2
dfdc = diff(f, c)

# The first line declares that ``c`` is a variable that some function
# can be differentiated with respect to. The next line is the function
# :math:`f` defined in the problem statement, and the third line
# performs the differentiation of ``f`` with respect to the variable
# ``c``.
# 
# It is convenient to introduce an expression for :math:`\mu_{n+\theta}`::

# mu_(n+theta)
mu_mid = (1.0-theta)*mu0 + theta*mu

# which is then used in the definition of the variational forms::

# Weak statement of the equations
L0 = c*q*dx - c0*q*dx + dt*dot(grad(mu_mid), grad(q))*dx
L1 = mu*v*dx - dfdc*v*dx - lmbda*dot(grad(c), grad(v))*dx
L = L0 + L1

# This is a statement of the time-discrete equations presented as part
# of the problem statement, using UFL syntax. The linear forms for the
# two equations can be summed into one form ``L``, and then the
# directional derivative of ``L`` can be computed to form the bilinear
# form which represents the Jacobian matrix::

# Compute directional derivative about u in the direction of du (Jacobian)
a = derivative(L, u, du)

# .. index::
#    single: Newton solver; (in Cahn-Hilliard demo)
# 
# The DOLFIN Newton solver requires a :py:class:`NonlinearProblem
# <dolfin.cpp.NonlinearProblem>` object to solve a system of nonlinear
# equations. Here, we are using the class ``CahnHilliardEquation``,
# which was declared at the beginning of the file, and which is a
# sub-class of :py:class:`NonlinearProblem
# <dolfin.cpp.NonlinearProblem>`. We need to instantiate objects of both
# ``CahnHilliardEquation`` and :py:class:`NewtonSolver
# <dolfin.cpp.NewtonSolver>`::

# Create nonlinear problem and Newton solver
problem = CahnHilliardEquation(a, L)
solver = NewtonSolver()
solver.parameters["linear_solver"] = "lu"
solver.parameters["convergence_criterion"] = "incremental"
solver.parameters["relative_tolerance"] = 1e-6

# The string ``"lu"`` passed to the Newton solver indicated that an LU
# solver should be used.  The setting of
# ``parameters["convergence_criterion"] = "incremental"`` specifies that
# the Newton solver should compute a norm of the solution increment to
# check for convergence (the other possibility is to use ``"residual"``,
# or to provide a user-defined check). The tolerance for convergence is
# specified by ``parameters["relative_tolerance"] = 1e-6``.
# 
# To run the solver and save the output to a VTK file for later visualization,
# the solver is advanced in time from :math:`t_{n}` to :math:`t_{n+1}` until
# a terminal time :math:`T` is reached::

# Output file
file = File("vtu-pvd_files/Cahn-Hilliard.pvd", "compressed")

# Step in time
t = 0.0
T = 50*dt
while (t < T):
    t += dt
    u0.vector()[:] = u.vector()
    solver.solve(problem, u.vector())
    file << (u.split()[0], t)

# The string ``"compressed"`` indicates that the output data should be
# compressed to reduce the file size. Within the time stepping loop, the
# solution vector associated with ``u`` is copied to ``u0`` at the
# beginning of each time step, and the nonlinear problem is solved by
# calling :py:func:`solver.solve(problem, u.vector())
# <dolfin.cpp.NewtonSolver.solve>`, with the new solution vector
# returned in :py:func:`u.vector() <dolfin.cpp.Function.vector>`. The
# ``c`` component of the solution (the first component of ``u``) is then
# written to file at every time step.
# Out:
# Newton iteration 0: r (abs) = 1.175e+03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.876e-01 (tol = 1.000e-10) r (rel) = 1.596e-04 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.360e-06 (tol = 1.000e-10) r (rel) = 2.859e-09 (tol = 1.000e-06)
# Newton solver finished in 3 iterations and 3 linear solver iterations.
# Newton iteration 0: r (abs) = 1.158e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.299e-01 (tol = 1.000e-10) r (rel) = 1.122e-02 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 8.944e-06 (tol = 1.000e-10) r (rel) = 7.726e-07 (tol = 1.000e-06)
# Newton solver finished in 3 iterations and 3 linear solver iterations.
# Newton iteration 0: r (abs) = 1.952e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.462e-01 (tol = 1.000e-10) r (rel) = 2.798e-02 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.385e-04 (tol = 1.000e-10) r (rel) = 7.092e-06 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.601e-11 (tol = 1.000e-10) r (rel) = 1.332e-12 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 4.072e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.545e+00 (tol = 1.000e-10) r (rel) = 6.248e-02 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.451e-03 (tol = 1.000e-10) r (rel) = 6.018e-05 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 6.046e-09 (tol = 1.000e-10) r (rel) = 1.485e-10 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 9.426e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.050e+01 (tol = 1.000e-10) r (rel) = 1.114e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.921e-02 (tol = 1.000e-10) r (rel) = 3.099e-04 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.068e-06 (tol = 1.000e-10) r (rel) = 1.133e-08 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 2.401e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.088e+01 (tol = 1.000e-10) r (rel) = 2.119e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.640e+00 (tol = 1.000e-10) r (rel) = 1.516e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 4.079e-02 (tol = 1.000e-10) r (rel) = 1.699e-04 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 8.322e-06 (tol = 1.000e-10) r (rel) = 3.466e-08 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.147e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.039e+02 (tol = 1.000e-10) r (rel) = 4.916e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.914e+01 (tol = 1.000e-10) r (rel) = 7.027e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 8.182e-01 (tol = 1.000e-10) r (rel) = 1.973e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.978e-04 (tol = 1.000e-10) r (rel) = 2.406e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 3.214e-09 (tol = 1.000e-10) r (rel) = 7.750e-12 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 2.982e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.050e+02 (tol = 1.000e-10) r (rel) = 6.875e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.190e+01 (tol = 1.000e-10) r (rel) = 7.346e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 4.902e-01 (tol = 1.000e-10) r (rel) = 1.644e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 6.914e-04 (tol = 1.000e-10) r (rel) = 2.319e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 3.512e-09 (tol = 1.000e-10) r (rel) = 1.178e-11 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 2.306e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.018e+02 (tol = 1.000e-10) r (rel) = 4.416e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 8.814e+00 (tol = 1.000e-10) r (rel) = 3.823e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.329e-01 (tol = 1.000e-10) r (rel) = 1.444e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.361e-04 (tol = 1.000e-10) r (rel) = 4.060e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 8.177e-09 (tol = 1.000e-10) r (rel) = 3.547e-11 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 1.282e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.573e+01 (tol = 1.000e-10) r (rel) = 4.347e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.812e+00 (tol = 1.000e-10) r (rel) = 2.973e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.581e-02 (tol = 1.000e-10) r (rel) = 2.793e-04 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 4.672e-06 (tol = 1.000e-10) r (rel) = 3.644e-08 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 8.614e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 3.752e+01 (tol = 1.000e-10) r (rel) = 4.356e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.800e+00 (tol = 1.000e-10) r (rel) = 3.251e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.978e-02 (tol = 1.000e-10) r (rel) = 3.457e-04 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 4.429e-06 (tol = 1.000e-10) r (rel) = 5.142e-08 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 8.642e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.962e+01 (tol = 1.000e-10) r (rel) = 3.427e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.498e+00 (tol = 1.000e-10) r (rel) = 1.733e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 6.345e-03 (tol = 1.000e-10) r (rel) = 7.342e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.485e-07 (tol = 1.000e-10) r (rel) = 1.719e-09 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 8.680e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 4.836e+01 (tol = 1.000e-10) r (rel) = 5.571e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.365e+00 (tol = 1.000e-10) r (rel) = 6.181e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.318e-01 (tol = 1.000e-10) r (rel) = 1.518e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.159e-04 (tol = 1.000e-10) r (rel) = 1.335e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 1.071e-10 (tol = 1.000e-10) r (rel) = 1.234e-12 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 7.353e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 4.291e+01 (tol = 1.000e-10) r (rel) = 5.835e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 4.311e+00 (tol = 1.000e-10) r (rel) = 5.864e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 9.507e-02 (tol = 1.000e-10) r (rel) = 1.293e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 5.655e-05 (tol = 1.000e-10) r (rel) = 7.691e-07 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.978e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.247e+01 (tol = 1.000e-10) r (rel) = 3.760e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 7.256e-01 (tol = 1.000e-10) r (rel) = 1.214e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.512e-03 (tol = 1.000e-10) r (rel) = 2.529e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.196e-09 (tol = 1.000e-10) r (rel) = 1.538e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.780e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.640e+01 (tol = 1.000e-10) r (rel) = 2.837e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.705e-01 (tol = 1.000e-10) r (rel) = 9.870e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.223e-03 (tol = 1.000e-10) r (rel) = 2.116e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.378e-09 (tol = 1.000e-10) r (rel) = 1.276e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.270e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.756e+01 (tol = 1.000e-10) r (rel) = 4.114e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.037e+00 (tol = 1.000e-10) r (rel) = 2.428e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 7.501e-03 (tol = 1.000e-10) r (rel) = 1.757e-04 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 4.702e-07 (tol = 1.000e-10) r (rel) = 1.101e-08 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.658e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.022e+01 (tol = 1.000e-10) r (rel) = 2.793e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.268e-01 (tol = 1.000e-10) r (rel) = 3.468e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 4.337e-05 (tol = 1.000e-10) r (rel) = 1.186e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.534e-12 (tol = 1.000e-10) r (rel) = 2.059e-13 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.016e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.230e+01 (tol = 1.000e-10) r (rel) = 3.063e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 4.365e-01 (tol = 1.000e-10) r (rel) = 1.087e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 9.313e-04 (tol = 1.000e-10) r (rel) = 2.319e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 5.057e-09 (tol = 1.000e-10) r (rel) = 1.259e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.438e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.364e+01 (tol = 1.000e-10) r (rel) = 3.966e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.160e-01 (tol = 1.000e-10) r (rel) = 1.501e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.296e-03 (tol = 1.000e-10) r (rel) = 3.768e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.714e-09 (tol = 1.000e-10) r (rel) = 2.825e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.283e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.080e+01 (tol = 1.000e-10) r (rel) = 2.520e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.568e-01 (tol = 1.000e-10) r (rel) = 3.659e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 6.992e-05 (tol = 1.000e-10) r (rel) = 1.632e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.787e-11 (tol = 1.000e-10) r (rel) = 4.172e-13 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 6.639e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 3.592e+01 (tol = 1.000e-10) r (rel) = 5.410e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.806e+00 (tol = 1.000e-10) r (rel) = 5.732e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 6.789e-02 (tol = 1.000e-10) r (rel) = 1.023e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 2.587e-05 (tol = 1.000e-10) r (rel) = 3.896e-07 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.063e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 3.545e+01 (tol = 1.000e-10) r (rel) = 7.003e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.719e+00 (tol = 1.000e-10) r (rel) = 7.347e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 9.082e-02 (tol = 1.000e-10) r (rel) = 1.794e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 6.571e-05 (tol = 1.000e-10) r (rel) = 1.298e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 3.689e-11 (tol = 1.000e-10) r (rel) = 7.286e-13 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 6.697e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.111e+01 (tol = 1.000e-10) r (rel) = 3.153e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.804e+00 (tol = 1.000e-10) r (rel) = 2.694e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.622e-02 (tol = 1.000e-10) r (rel) = 3.915e-04 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 5.877e-06 (tol = 1.000e-10) r (rel) = 8.776e-08 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.908e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.890e+01 (tol = 1.000e-10) r (rel) = 3.850e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 8.223e-01 (tol = 1.000e-10) r (rel) = 1.675e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.686e-03 (tol = 1.000e-10) r (rel) = 5.474e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 4.273e-08 (tol = 1.000e-10) r (rel) = 8.707e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.964e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.551e+01 (tol = 1.000e-10) r (rel) = 3.124e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.089e-01 (tol = 1.000e-10) r (rel) = 1.025e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.166e-03 (tol = 1.000e-10) r (rel) = 2.349e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 8.526e-09 (tol = 1.000e-10) r (rel) = 1.718e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.553e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.888e+01 (tol = 1.000e-10) r (rel) = 3.400e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 7.778e-01 (tol = 1.000e-10) r (rel) = 1.401e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.112e-03 (tol = 1.000e-10) r (rel) = 3.804e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 2.649e-08 (tol = 1.000e-10) r (rel) = 4.770e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 6.326e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.961e+01 (tol = 1.000e-10) r (rel) = 4.680e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.644e+00 (tol = 1.000e-10) r (rel) = 2.599e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.088e-02 (tol = 1.000e-10) r (rel) = 1.720e-04 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.193e-07 (tol = 1.000e-10) r (rel) = 1.137e-08 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.205e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 3.745e+01 (tol = 1.000e-10) r (rel) = 8.906e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.289e+00 (tol = 1.000e-10) r (rel) = 7.822e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 4.596e-02 (tol = 1.000e-10) r (rel) = 1.093e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.141e-05 (tol = 1.000e-10) r (rel) = 2.713e-07 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.532e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.306e+01 (tol = 1.000e-10) r (rel) = 2.361e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.059e-01 (tol = 1.000e-10) r (rel) = 5.529e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.834e-04 (tol = 1.000e-10) r (rel) = 6.930e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.259e-10 (tol = 1.000e-10) r (rel) = 1.312e-11 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.392e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 7.876e+00 (tol = 1.000e-10) r (rel) = 2.322e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.056e-01 (tol = 1.000e-10) r (rel) = 3.114e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 4.555e-05 (tol = 1.000e-10) r (rel) = 1.343e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.918e-12 (tol = 1.000e-10) r (rel) = 2.924e-13 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 2.308e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.783e+00 (tol = 1.000e-10) r (rel) = 2.506e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.764e-02 (tol = 1.000e-10) r (rel) = 1.631e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.606e-06 (tol = 1.000e-10) r (rel) = 1.563e-07 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 1.969e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.108e+00 (tol = 1.000e-10) r (rel) = 2.594e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.356e-02 (tol = 1.000e-10) r (rel) = 1.704e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.248e-06 (tol = 1.000e-10) r (rel) = 1.649e-07 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 1.998e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.141e+00 (tol = 1.000e-10) r (rel) = 2.573e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.233e-02 (tol = 1.000e-10) r (rel) = 2.619e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.147e-05 (tol = 1.000e-10) r (rel) = 5.743e-07 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 2.551e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 7.014e+00 (tol = 1.000e-10) r (rel) = 2.750e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.136e-01 (tol = 1.000e-10) r (rel) = 8.374e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.422e-04 (tol = 1.000e-10) r (rel) = 9.495e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 3.397e-10 (tol = 1.000e-10) r (rel) = 1.331e-11 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.672e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 7.068e+00 (tol = 1.000e-10) r (rel) = 1.513e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.709e-01 (tol = 1.000e-10) r (rel) = 5.799e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.170e-04 (tol = 1.000e-10) r (rel) = 4.644e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 3.429e-10 (tol = 1.000e-10) r (rel) = 7.340e-12 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.602e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 5.210e+01 (tol = 1.000e-10) r (rel) = 9.300e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 7.017e+00 (tol = 1.000e-10) r (rel) = 1.253e-01 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 2.018e-01 (tol = 1.000e-10) r (rel) = 3.601e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 2.211e-04 (tol = 1.000e-10) r (rel) = 3.947e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 2.974e-10 (tol = 1.000e-10) r (rel) = 5.309e-12 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 6.980e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 4.139e+01 (tol = 1.000e-10) r (rel) = 5.929e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 6.575e+00 (tol = 1.000e-10) r (rel) = 9.420e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.103e-01 (tol = 1.000e-10) r (rel) = 4.445e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.557e-04 (tol = 1.000e-10) r (rel) = 1.083e-05 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 4.762e-09 (tol = 1.000e-10) r (rel) = 6.823e-11 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 6.676e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.725e+01 (tol = 1.000e-10) r (rel) = 2.584e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 7.717e-01 (tol = 1.000e-10) r (rel) = 1.156e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.081e-03 (tol = 1.000e-10) r (rel) = 4.615e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 6.764e-08 (tol = 1.000e-10) r (rel) = 1.013e-09 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 5.728e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 3.743e+01 (tol = 1.000e-10) r (rel) = 6.534e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.523e+00 (tol = 1.000e-10) r (rel) = 9.642e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.805e-01 (tol = 1.000e-10) r (rel) = 3.152e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 2.261e-04 (tol = 1.000e-10) r (rel) = 3.947e-06 (tol = 1.000e-06)
# Newton iteration 5: r (abs) = 3.809e-10 (tol = 1.000e-10) r (rel) = 6.650e-12 (tol = 1.000e-06)
# Newton solver finished in 6 iterations and 6 linear solver iterations.
# Newton iteration 0: r (abs) = 5.165e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.668e+01 (tol = 1.000e-10) r (rel) = 3.230e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 5.335e-01 (tol = 1.000e-10) r (rel) = 1.033e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.301e-03 (tol = 1.000e-10) r (rel) = 2.519e-05 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.214e-08 (tol = 1.000e-10) r (rel) = 2.351e-10 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.274e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.776e+01 (tol = 1.000e-10) r (rel) = 8.479e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.241e+00 (tol = 1.000e-10) r (rel) = 9.900e-02 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 6.450e-02 (tol = 1.000e-10) r (rel) = 1.970e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 2.960e-05 (tol = 1.000e-10) r (rel) = 9.039e-07 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.467e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 8.670e+00 (tol = 1.000e-10) r (rel) = 2.501e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.408e-01 (tol = 1.000e-10) r (rel) = 4.060e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 9.689e-05 (tol = 1.000e-10) r (rel) = 2.795e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.273e-11 (tol = 1.000e-10) r (rel) = 2.098e-12 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 2.898e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 7.050e+00 (tol = 1.000e-10) r (rel) = 2.433e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.835e-01 (tol = 1.000e-10) r (rel) = 6.333e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.320e-04 (tol = 1.000e-10) r (rel) = 4.555e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 7.467e-11 (tol = 1.000e-10) r (rel) = 2.576e-12 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 4.215e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 1.108e+01 (tol = 1.000e-10) r (rel) = 2.628e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.776e-01 (tol = 1.000e-10) r (rel) = 4.213e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 6.678e-05 (tol = 1.000e-10) r (rel) = 1.584e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.527e-11 (tol = 1.000e-10) r (rel) = 3.623e-13 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 2.071e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 3.094e+01 (tol = 1.000e-10) r (rel) = 1.494e+00 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 3.173e+00 (tol = 1.000e-10) r (rel) = 1.532e-01 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 4.732e-02 (tol = 1.000e-10) r (rel) = 2.285e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 1.250e-05 (tol = 1.000e-10) r (rel) = 6.034e-07 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.727e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 7.985e+00 (tol = 1.000e-10) r (rel) = 2.142e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 7.755e-02 (tol = 1.000e-10) r (rel) = 2.081e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.798e-05 (tol = 1.000e-10) r (rel) = 4.824e-07 (tol = 1.000e-06)
# Newton solver finished in 4 iterations and 4 linear solver iterations.
# Newton iteration 0: r (abs) = 3.061e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 4.836e+00 (tol = 1.000e-10) r (rel) = 1.580e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.536e-01 (tol = 1.000e-10) r (rel) = 5.018e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 1.327e-04 (tol = 1.000e-10) r (rel) = 4.336e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.891e-11 (tol = 1.000e-10) r (rel) = 3.231e-12 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 3.587e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 9.117e+00 (tol = 1.000e-10) r (rel) = 2.542e-01 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 1.661e-01 (tol = 1.000e-10) r (rel) = 4.631e-03 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 9.519e-05 (tol = 1.000e-10) r (rel) = 2.654e-06 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 4.995e-11 (tol = 1.000e-10) r (rel) = 1.393e-12 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.
# Newton iteration 0: r (abs) = 1.733e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
# Newton iteration 1: r (abs) = 2.558e+01 (tol = 1.000e-10) r (rel) = 1.476e+00 (tol = 1.000e-06)
# Newton iteration 2: r (abs) = 2.594e+00 (tol = 1.000e-10) r (rel) = 1.497e-01 (tol = 1.000e-06)
# Newton iteration 3: r (abs) = 3.797e-02 (tol = 1.000e-10) r (rel) = 2.191e-03 (tol = 1.000e-06)
# Newton iteration 4: r (abs) = 9.776e-06 (tol = 1.000e-10) r (rel) = 5.642e-07 (tol = 1.000e-06)
# Newton solver finished in 5 iterations and 5 linear solver iterations.

# %%
# Saves as .py file

# !ipython nbconvert Cahn-Hilliard.ipynb --to script
# Out:
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Cahn-Hilliard.ipynb to script
# [NbConvertApp] Writing 13391 bytes to Cahn-Hilliard.py
